# %% [markdown]
# question no 1

# %%
class Perceptron:
    def __init__(self, input_size, lr=0.1, epochs=100):
        self.W = np.zeros(input_size)
        self.b = 0
        self.lr = lr
        self.epochs = epochs

# %%
def step_function(self, x):
    return 1 if x >= 0 else 0

# %%
def train(self, X, y):
        for epoch in range(self.epochs):
            for x, y_true in zip(X, y):
                y_pred = self.step_function(np.dot(self.W, x) + self.b)
                error = y_true - y_pred

                self.W += self.lr * error * x
                self.b += self.lr * error

# %% [markdown]
# question no 2

# %%
import numpy as np

class Perceptron:
    def __init__(self, input_size, lr=0.1, epochs=100):
        self.W = np.zeros(input_size)
        self.b = 0
        self.lr = lr
        self.epochs = epochs

    def step_function(self, x):
        return 1 if x >= 0 else 0

    def predict(self, x):
        return self.step_function(np.dot(self.W, x) + self.b)

    def train(self, X, y):
        for epoch in range(self.epochs):
            for x, y_true in zip(X, y):
                y_pred = self.predict(x)
                error = y_true - y_pred
                self.W += self.lr * error * x
                self.b += self.lr * error

X = np.array([[0, 0], [0, 1], [1, 0], [1, 1]])
y = np.array([0, 0, 0, 1])

perceptron = Perceptron(input_size=2, lr=0.1, epochs=100)
perceptron.train(X, y)

for x in X:
    print(f"Input: {x}, Predicted Output: {perceptron.predict(x)}")
# Out:
# Input: [0 0], Predicted Output: 0
# Input: [0 1], Predicted Output: 0
# Input: [1 0], Predicted Output: 0
# Input: [1 1], Predicted Output: 1

# %% [markdown]
# question no 3

# %%
perceptron = Perceptron(input_size=2, lr=0.01, epochs=100)
perceptron.train(X, y)

# %%
perceptron = Perceptron(input_size=2, lr=0.1, epochs=200)
perceptron.train(X, y)

# %%
X_test = np.array([[0.1, 0.1], [0.9, 0.9], [0.5, 0.5]])
for x in X_test:
    print(f"Input: {x}, Predicted Output: {perceptron.predict(x)}")
# Out:
# Input: [0.1 0.1], Predicted Output: 0
# Input: [0.9 0.9], Predicted Output: 1
# Input: [0.5 0.5], Predicted Output: 0
